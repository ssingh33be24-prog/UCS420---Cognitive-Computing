# %%
#que1

# %%
roll_number=1024170049
l=[]
while roll_number>0:
    tba=roll_number%10
    roll_number=roll_number//10
    l.append(tba*10)
l.reverse()
print(l)
# Out:
# [10, 0, 20, 40, 10, 70, 0, 0, 40, 90]

# %%
#(i)
print(l)
# Out:
# [10, 0, 20, 40, 10, 70, 0, 0, 40, 90]

# %%
#(ii)
l.append(30)
print(l)
l.insert(2,80)
print(l)
# Out:
# [10, 0, 20, 40, 10, 70, 0, 0, 40, 90, 30]
# [10, 0, 80, 20, 40, 10, 70, 0, 0, 40, 90, 30]

# %%
#(iii)
l.pop()
print(l)
l.remove(80)
print(l)
# Out:
# [10, 0, 80, 20, 40, 10, 70, 0, 0, 40, 90]
# [10, 0, 20, 40, 10, 70, 0, 0, 40, 90]

# %%
#(iv)
l2=[i for i in l]
l2.sort()
print(l2)
l2.sort(reverse=True)
print(l2)
# Out:
# [0, 0, 0, 10, 10, 20, 40, 40, 70, 90]
# [90, 70, 40, 40, 20, 10, 10, 0, 0, 0]

# %%
#(v)
print(l[0:3])
print(l[-1:-4:-1])
# Out:
# [90, 70, 40]
# [0, 0, 0]

# %%
#(vi)
avg_l=sum(l)/len(l)
new_l=[i for i in l if i>avg_l]
print(new_l)
# Out:
# [90, 70, 40, 40]

# %%
#que 2

# %%
scores=tuple(l[0:8])
print(scores)
# Out:
# (90, 70, 40, 40, 20, 10, 10, 0)

# %%
#(i)
max_score=max(scores)
min_score=min(scores)
print("maximum score is",max_score)
print("maximum score index is",scores.index(max_score))
print("minimum score is",min_score)
print("frequency of minimum score is",scores.count(min_score))
# Out:
# maximum score is 90
# maximum score index is 0
# minimum score is 0
# frequency of minimum score is 1

# %%
#(ii)
l_scores=list(scores)
l_scores=l_scores[-1::-1]
print(l_scores)
# Out:
# [0, 10, 10, 20, 40, 40, 70, 90]

# %%
print("scores tupple is",scores)
num=int(input("Enter a score"))
if(num in scores):
    print(scores.index(num))

else:
    print("not present")
# Out:
# scores tupple is (90, 70, 40, 40, 20, 10, 10, 0)
# Enter a score 50
# not present

# %%
scores[4]=90
print(scores)

#It is because tupples are immutuable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 scores[4]=90
#       2 print(scores)
#
# TypeError: 'tuple' object does not support item assignment

# %%
first_score,second_score,*all_remaining_scores=scores
print(first_score)
print(second_score)
print(all_remaining_scores)
# Out:
# 90
# 70
# [40, 40, 20, 10, 10, 0]

# %%
#que5

# %%
my_dict = { "name": "Surya", "roll_no": "1024170062", "branch": "COPC", "age": 20, "city": "Greater Noida" }
print(my_dict)
# Out:
# {'name': 'Surya', 'roll_no': '1024170062', 'branch': 'COPC', 'age': 20, 'city': 'Greater Noida'}

# %%
my_dict["Location"]=my_dict.pop("city")
print(my_dict)
# Out:
# {'name': 'Surya', 'roll_no': '1024170062', 'branch': 'COPC', 'age': 20, 'Location': 'Greater Noida'}

# %%
my_dict["CGPA"]=7.5
print(my_dict)
# Out:
# {'name': 'Surya', 'roll_no': '1024170062', 'branch': 'COPC', 'age': 20, 'Location': 'Greater Noida', 'CGPA': 7.5}

# %%
my_dict["age"]=my_dict["age"]+1;
print(my_dict)
# Out:
# {'name': 'Surya', 'roll_no': '1024170062', 'branch': 'COPC', 'age': 21, 'Location': 'Greater Noida', 'CGPA': 7.5}

# %%
del_pop=my_dict.copy()
del_pop.pop("branch")
print(del_pop)
# Out:
# {'name': 'Surya', 'roll_no': '1024170062', 'age': 21, 'Location': 'Greater Noida', 'CGPA': 7.5}

# %%
del_del=my_dict.copy()
del(del_del["branch"])
print(del_del)
# Out:
# {'name': 'Surya', 'roll_no': '1024170062', 'age': 21, 'Location': 'Greater Noida', 'CGPA': 7.5}

# %%
for key, value in my_dict.items():
    print(key,"-->", value)
# Out:
# name --> Surya
# roll_no --> 1024170062
# branch --> COPC
# age --> 21
# Location --> Greater Noida
# CGPA --> 7.5

# %%
if("email"in my_dict):
    print(my_dict["email"])
else:
    print("does not exist")
# Out:
# does not exist

# %%
friend_dict={ "name": "Shubham(Fanta)", "roll_no": "1024030409", "branch": "COE", "age": 20, "Location": "Odisha" }
print(friend_dict)
# Out:
# {'name': 'Shubham(Fanta)', 'roll_no': '1024030409', 'branch': 'COE', 'age': 20, 'Location': 'Odisha'}

# %%
merged_dict={**my_dict,**friend_dict}
print(merged_dict)
# Out:
# {'name': 'Shubham(Fanta)', 'roll_no': '1024030409', 'branch': 'COE', 'age': 20, 'Location': 'Odisha', 'CGPA': 7.5}

# %%
new_dict={key:value for (key,value) in my_dict.items() if(type(value)==str)}
print(new_dict)
# Out:
# {'name': 'Surya', 'roll_no': '1024170062', 'branch': 'COPC', 'Location': 'Greater Noida'}

# %%
#que 3
import random
random.seed(1024170062)

# %%
numbers=[random.randint(100,900) for i in range(100)]
print(numbers)
# Out:
# [338, 836, 388, 306, 441, 734, 853, 786, 778, 650, 190, 513, 888, 513, 215, 883, 168, 766, 592, 660, 549, 114, 457, 541, 690, 517, 390, 520, 439, 268, 715, 459, 421, 857, 255, 161, 751, 292, 625, 498, 171, 886, 589, 896, 193, 480, 803, 186, 402, 447, 166, 629, 146, 299, 114, 504, 612, 705, 779, 773, 451, 466, 445, 806, 730, 327, 791, 639, 464, 182, 433, 391, 174, 607, 571, 634, 332, 833, 570, 450, 123, 331, 660, 838, 680, 379, 496, 178, 341, 345, 633, 218, 231, 461, 292, 497, 186, 664, 156, 264]

# %%
odd_num=[i for i in numbers if i%2!=0]
print(odd_num)
print("count is:", len(odd_num))
# Out:
# [441, 853, 513, 513, 215, 883, 549, 457, 541, 517, 439, 715, 459, 421, 857, 255, 161, 751, 625, 171, 589, 193, 803, 447, 629, 299, 705, 779, 773, 451, 445, 327, 791, 639, 433, 391, 607, 571, 833, 123, 331, 379, 341, 345, 633, 231, 461, 497]
# count is: 48

# %%
even_num=[i for i in numbers if i%2==0]
print(even_num)
print("count is:", len(even_num))
# Out:
# [338, 836, 388, 306, 734, 786, 778, 650, 190, 888, 168, 766, 592, 660, 114, 690, 390, 520, 268, 292, 498, 886, 896, 480, 186, 402, 166, 146, 114, 504, 612, 466, 806, 730, 464, 182, 174, 634, 332, 570, 450, 660, 838, 680, 496, 178, 218, 292, 186, 664, 156, 264]
# count is: 52

# %%
def prime(i):
    isprime=True
    if i<2:
        isprime=False
        return isprime
    for j in range(2,(i//2)+1,1):
        if i%j==0:
            isprime=False
    return isprime
prime_number=[k for k in numbers if prime(k)]
print(prime_number)
print("count is:",len(prime_number))
# Out:
# [853, 883, 457, 541, 439, 421, 857, 751, 193, 773, 433, 607, 571, 331, 379, 461]
# count is: 16

# %%
most_frequent = max(set(numbers), key=numbers.count)
print("Most frequent number:", most_frequent)
print("Frequency:", numbers.count(most_frequent))
# Out:
# Most frequent number: 513
# Frequency: 2

# %%
#que 4
roll_num=set()
num=1024170049
while num>0:
    tba=num%10
    num=num//10
    roll_num.add(tba)
print(roll_num)
# Out:
# {0, 1, 2, 4, 7, 9}

# %%
A={i*7 for i in roll_num}
B={i*9 for i in roll_num}
print(A)
print(B)
# Out:
# {0, 7, 14, 49, 28, 63}
# {0, 36, 9, 81, 18, 63}

# %%
print(A.union(B))
# Out:
# {0, 36, 7, 9, 14, 49, 81, 18, 28, 63}

# %%
print(A.intersection(B))
# Out:
# {0, 63}

# %%
print(A.difference(B))
print(B.difference(A))
# Out:
# {49, 28, 14, 7}
# {81, 9, 18, 36}

# %%
print(A.symmetric_difference(B))
# Out:
# {7, 9, 14, 81, 18, 28, 36, 49}

# %%
print(A.issubset(B))
print(B.issuperset(A))
# Out:
# False
# False

# %%
X=int(input("Enter number to be removed"))
A.discard(X)
# Out:
# Enter number to be removed36
